# %% [markdown]
# ### Step 1) Importing priliminary required libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Step 2) Importing Data

# %%
df = pd.read_csv("C:/Users/HP/OneDrive/Desktop/Flip Robo/Practice Projects/medical_cost_insurance.csv")

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Observations
# ##### Total of 7 variables that includes 6 features (age,sex,bmi,children,smoker and region) and 1 label (charges)
# ##### As per the above data visible age, bmi, children and charges seems to be numerical data and sex, smoker, region are categorical data

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
df.tail(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %% [markdown]
# ### Observations
# ##### Children feature has 4 values 0,1,2,3

# %% [markdown]
# ### Step 3) Checking the types of data in dataset

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# ### Observation
# ##### There are 3 types of data int,float,object

# %% [markdown]
# ### Step 4) Checking the dimension of the data set

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ### Observation
# ##### The dataset contains Rows-1338 and Columns-7

# %% [markdown]
# ### Step 5) Info of the Data Set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# #### Observation
# ##### No of rows is equal to non null values which shows no null values present
# ##### 2 features have float value, 2 have int values and 3 are object type
# ##### memory usage 73.3KB

# %% [markdown]
# ### Step 6) Checking Null values

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.isnull().sum().sum() ### Gives null value in entire dataset
# Out:
# 0

# %% [markdown]
# #### Observations
# ##### No null values

# %% [markdown]
# #### Step 7) Futher checking if there are blanks in the dataset

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64
#
#
# male      676
# female    662
# Name: sex, dtype: int64
#
#
# 32.300    13
# 28.310     9
# 30.495     8
# 30.875     8
# 31.350     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: bmi, Length: 548, dtype: int64
#
#
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64
#
#
# no     1064
# yes     274
# Name: smoker, dtype: int64
#
#
# southeast    364
# ...

# %%
df.nunique().to_frame('No of Unique Values')
# Out:
#           No of Unique Values
# age                        47
# sex                         2
# bmi                       548
# children                    6
# smoker                      2
# region                      4
# charges                  1337

# %% [markdown]
# #### Observation
# ##### No blank space

# %% [markdown]
# ### Step 8) Checking Duplicate Rows if any checking the same and deleting the duplicate row

# %%
df.duplicated().sum()
# Out:
# 1

# %%
duplicated_rows = df[df.duplicated()]

# %%
duplicated_rows
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1337, 7)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Observation
# ##### 1 duplicate row present hence deleted the duplicate row, no of rows no 1337 and columns remains intact 7

# %% [markdown]
# ### Step 9) Statistical details of the dataset

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# #### Observation
# ##### Count of all variables are same hence no missing values
# ##### Mean is very close to median in all columns except in Charges column wherein Mean>Median i.e the positive skewness in charges columns but since it is the target variable hence no skweness treatment required
# ##### Outlier present in children, bmi column

# %% [markdown]
# #### Step 10) Data Visualization - Univariate Analysis

# %% [markdown]
# #### Visualization of categorical data using countplot

# %%
g = sns.countplot(x='sex',data=df)
print(df['sex'].value_counts())
plt.show()
# Out:
# male      675
# female    662
# Name: sex, dtype: int64

# %% [markdown]
# #### Observation
# ##### Count of Male and Female are almost equal

# %%
g = sns.countplot(x='children',data=df)
print(df['children'].value_counts())
plt.show()
# Out:
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# #### Observation
# ##### Children being a categorical variable does not require any treatment

# %%
g = sns.countplot(x='region',data=df)
print(df['region'].value_counts())
plt.show()
# Out:
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: region, dtype: int64

# %%
g = sns.countplot(x='smoker',data=df)
print(df['smoker'].value_counts())
plt.show()
# Out:
# no     1063
# yes     274
# Name: smoker, dtype: int64

# %% [markdown]
# #### Observation
# ##### Non Smoker >>> Smoker

# %%
cg = sns.distplot(df['bmi'])
print(df['bmi'].value_counts())
plt.show()
# Out:
# 32.30    13
# 28.31     9
# 30.80     8
# 31.35     8
# 28.88     8
#          ..
# 46.20     1
# 23.80     1
# 44.77     1
# 32.12     1
# 30.97     1
# Name: bmi, Length: 548, dtype: int64

# %% [markdown]
# #### Observation
# ##### BMI variable is uniformly distributed

# %%
cg = sns.distplot(df['age'])
print(df['age'].value_counts())
plt.show()
# Out:
# 18    69
# 19    67
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %% [markdown]
# #### Observation
# ##### Uniformly distribution no skewness

# %%
cg = sns.distplot(df['charges'])
print(df['charges'].value_counts())
plt.show()
# Out:
# 16884.92400    1
# 2117.33885     1
# 2221.56445     1
# 19798.05455    1
# 13063.88300    1
#               ..
# 7345.08400     1
# 26109.32905    1
# 28287.89766    1
# 1149.39590     1
# 29141.36030    1
# Name: charges, Length: 1337, dtype: int64

# %% [markdown]
# #### Observation
# ##### The data is skewed towards the right, Majority data lies between 0 to 2000 and has outliers but being target variable outlier treatment not required

# %% [markdown]
# ### Step 11) Bivariate Analysis

# %%
sns.scatterplot(x='bmi',y='charges',data=df,palette='colorblind')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# #### Observation
# ##### As bmi increases the charges increases but it not a exact limear relationship

# %%
sns.scatterplot(x='age',y='charges',data=df,palette='spring_r')
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %% [markdown]
# #### Observation
# ##### As age increases the charges also increases

# %%
sns.barplot(x='sex',y='charges',data=df)
plt.show()

# %% [markdown]
# #### Observation
# ##### No majot difference in terms of charges in case of male and female

# %%
sns.barplot(x='children',y='charges',data=df)
plt.show()

# %%
ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='children', data=df, palette='Set3')

# %% [markdown]
# #### Observation
# ##### If analysed regionwise i.e. souteast southwest and northwest depicts medical cost high in case of no of children 2,3,4

# %%
sns.barplot(x='smoker',y='charges',data=df)
plt.show()

# %% [markdown]
# #### Observation
# ##### Charges for smoker are very high

# %%
sns.barplot(x='region',y='charges',data=df,palette='Greys')
plt.show()

# %% [markdown]
# #### Observation
# ##### Medical charges are highest in case of Southeast region and lowest in southwest region

# %%
ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='region', y='charges', hue='sex', data=df, palette='mako')

# %% [markdown]
# #### Observation
# ##### Charges in northeast are almost equal for male and female

# %%
ax = plt.subplots(1,1, figsize=(12,8))
ax = sns.barplot(x = 'region', y = 'charges',hue='smoker', data=df, palette='cool')

# %% [markdown]
# #### Observation
# ##### Smoker have very high charges as compared to non smoker
# #### Smoker are highest in southeast region

# %%
ax = sns.lmplot(x = 'age', y = 'charges', data=df, hue='smoker', palette='Set1')

# %% [markdown]
# #### Observation : Although increase in age increases medical cost but in case of smoker the cost is very high

# %%
ax = sns.scatterplot(x = 'bmi', y = 'charges', data=df, hue='smoker', palette='Set2')

# %% [markdown]
# #### Observation : Although increase in BMI increases medical cost but in case of smoker the cost is very high

# %%
ax = sns.lmplot(x = 'children', y = 'charges', data=df, hue='smoker', palette='Set3')

# %% [markdown]
# #### Observation : People with more than 5 children do not smoke and charges high in case of smoker

# %% [markdown]
# ### Step 12) Multivatiate Analysis

# %%
sns.pairplot(data=df,palette="Dark2")
plt.show()

# %% [markdown]
# ### Step 13) Checking outliers

# %%
sns.boxplot(x='age',data=df)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# #### Observation
# ##### No outliers

# %%
sns.boxplot(x='bmi',data=df)
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
from scipy.stats import zscore

# %%
outlier = df['bmi']

# %%
z=np.abs(zscore(outlier))

# %%
z
# Out:
# 0       0.453160
# 1       0.509422
# 2       0.383155
# 3       1.305052
# 4       0.292456
#           ...
# 1333    0.050269
# 1334    0.206053
# 1335    1.014490
# 1336    0.797524
# 1337    0.261299
# Name: bmi, Length: 1337, dtype: float64

# %%
np.where(z>3)
# Out:
# (array([ 116,  846, 1046, 1316], dtype=int64),)

# %% [markdown]
# #### Observation since there are only 4 rows where z>3 we can drop the rows as these will not impact analysis

# %%
df1 =df[(z<3)]

# %%
df1
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1333 rows x 7 columns]

# %%
df1.shape
# Out:
# (1333, 7)

# %% [markdown]
# ### Step 14) Checking Skewness

# %%
df1.skew()
# Out:
# age         0.052714
# bmi         0.205541
# children    0.934451
# charges     1.517177
# dtype: float64

# %% [markdown]
# #### Observation
# ##### There is skewness in charges and children but charges is target variable and skewness is categorical variable both cases skewness cannot be removed

# %% [markdown]
# ### Step 15) Encoding Categorical Column

# %%
df1[['sex', 'smoker', 'region']] = df1[['sex', 'smoker', 'region']].astype('category')
df1.dtypes
# Out:
# age            int64
# sex         category
# bmi          float64
# children       int64
# smoker      category
# region      category
# charges      float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit(df1.sex)
df1.sex = label.transform(df1.sex)
label.fit(df1.smoker)
df1.smoker = label.transform(df1.smoker)
label.fit(df1.region)
df1.region = label.transform(df1.region)
df1.dtypes
# Out:
# age           int64
# sex           int32
# bmi         float64
# children      int64
# smoker        int32
# region        int32
# charges     float64
# dtype: object

# %% [markdown]
# ### Step 16) Correlationship between feature and label

# %%
df1.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.017987  0.118978  0.041406 -0.024390  0.002473  0.300658
# sex      -0.017987  1.000000  0.037046  0.019357  0.076510  0.003641  0.057923
# bmi       0.118978  0.037046  1.000000  0.018058  0.002264  0.155889  0.200868
# children  0.041406  0.019357  0.018058  1.000000  0.006744  0.016924  0.066957
# smoker   -0.024390  0.076510  0.002264  0.006744  1.000000 -0.002510  0.786519
# region    0.002473  0.003641  0.155889  0.016924 -0.002510  1.000000 -0.006743
# charges   0.300658  0.057923  0.200868  0.066957  0.786519 -0.006743  1.000000

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(), annot=True,cmap='cool',linewidth=0.3,linecolor='grey')
plt.xlabel('Figure',fontsize=12)
plt.title("Correlation Between Feature And Variable",fontsize=15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Step 17) Visualize Corelationship between label and features using bar plot

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Feature',fontsize=10)
plt.ylabel('Target',fontsize=10)
plt.show()

# %% [markdown]
# #### Observation
# ##### Charges has strong correlation with smoking

# %% [markdown]
# ### Step 18) Separating Independent and Target Variable

# %%
x = df1.drop('charges',axis=1)
y = df1['charges']

# %%
x.shape
# Out:
# (1333, 6)

# %%
y.shape
# Out:
# (1333,)

# %% [markdown]
# ### Step 19) Scaling the data using standard scaler to overcome the issue of biasness

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.443917 -1.006775 -0.450191 -0.909922  1.970478  1.342851
# 1    -1.515225  0.993271  0.527991 -0.080854 -0.507491  0.438800
# 2    -0.802147  0.993271  0.399678  1.577282 -0.507491  0.438800
# 3    -0.445607  0.993271 -1.315891 -0.909922 -0.507491 -0.465250
# 4    -0.516915  0.993271 -0.286883 -0.909922 -0.507491 -0.465250
# ...        ...       ...       ...       ...       ...       ...
# 1328  0.766626  0.993271  0.061396  1.577282 -0.507491 -0.465250
# 1329 -1.515225 -1.006775  0.219705 -0.909922 -0.507491 -1.369301
# 1330 -1.515225 -1.006775  1.041245 -0.909922 -0.507491  0.438800
# 1331 -1.301302 -1.006775 -0.800137 -0.909922 -0.507491  1.342851
# 1332  1.551013 -1.006775 -0.255221 -0.909922  1.970478 -0.465250
#
# [1333 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1333, dtype: float64

# %% [markdown]
# ### Step 20) Checking multicollinearity with help of Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Values  Features
# 0    1.017356       age
# 1    1.008073       sex
# 2    1.041622       bmi
# 3    1.002544  children
# 4    1.006479    smoker
# 5    1.025430    region

# %% [markdown]
# #### Observation
# ##### Since VIF values are less than 10 no mulitcolinearity

# %% [markdown]
# ### Step 21) Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as knn
from sklearn.model_selection import cross_val_score

# %%
maxAcc = 0
maxRs = 0
for i in range(1,300):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc > maxAcc:
        maxAcc = acc
        maxRs= i
print('Max r2 score is: ',maxAcc, 'on Random State', maxRs)
# Out:
# Max r2 score is:  0.796307560668144 on Random State 12

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=maxRs)

# %% [markdown]
# ### Appling Linear Regression and cross validation score

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
pred_lr = lr.predict(x_test)
pred_train = lr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2_score:  0.796307560668144
# R2 score on training data:  0.7283115193647449
# Mean Absolute Error:  3752.812437772448
# Mean Squared Error:  31441486.580109227
# Root Mean Squared Error:  5607.270867374718

# %%
score = cross_val_score(lr,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lr)-(score.mean()))*100)
# Out:
# [0.76244183 0.70819898 0.775179   0.73289379 0.75587313]
# 0.7469173454313714
# Difference between R2 Score and Cross Validation Score:  4.9390215236772566

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lr, y= y_test, color = 'b')
plt.plot(pred_lr,pred_lr,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Linear Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### Applying Random Forest Regressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_RFR))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score:  0.8770867104358572
# R2 score on training data:  0.9730255458596784
# Mean Absolute Error:  2444.372066700627
# Mean Squared Error:  18972606.725239817
# Root Mean Squared Error:  4355.755586030949

# %%
score = cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_RFR)-(score.mean()))*100)
# Out:
# [0.85121817 0.77120537 0.86374091 0.82948476 0.85135498]
# 0.8334008369454983
# Difference between R2 Score and Cross Validation Score:  4.368587349035891

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_RFR, y= y_test, color = 'b')
plt.plot(pred_RFR,pred_RFR,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Random Forest Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### Applying KNeighbor Regressor

# %%
KNN = knn()
KNN.fit(x_train, y_train)
pred_KNN = KNN.predict(x_test)
pred_train = KNN.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_KNN))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_KNN))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_KNN))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# R2_score:  0.8489151254352738
# R2 score on training data:  0.8535870310372797
# Mean Absolute Error:  2987.6179060575
# Mean Squared Error:  23321106.42724974
# Root Mean Squared Error:  4829.193144537681

# %%
score = cross_val_score(KNN,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_KNN)-(score.mean()))*100)
# Out:
# [0.82380042 0.75518371 0.83689594 0.80187345 0.80757419]
# 0.8050655418851447
# Difference between R2 Score and Cross Validation Score:  4.384958355012913

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_KNN, y= y_test, color = 'b')
plt.plot(pred_KNN,pred_KNN,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('KNeighbors Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### Applying Gradient Boosting Regressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_gbr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_gbr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_gbr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# R2_score:  0.8974834655043717
# R2 score on training data:  0.8885960533408054
# Mean Absolute Error:  2358.834703466764
# Mean Squared Error:  15824211.512987189
# Root Mean Squared Error:  3977.965750605099

# %%
score = cross_val_score(gbr,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_gbr)-(score.mean()))*100)
# Out:
# [0.87374203 0.79759153 0.88830683 0.84774444 0.85970761]
# 0.8534184874647002
# Difference between R2 Score and Cross Validation Score:  4.406497803967158

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_gbr, y= y_test, color = 'grey')
plt.plot(pred_gbr,pred_gbr,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Gradient Boosting Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### Applying Lasso Regression

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lasso))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score:  0.7962935423152823
# R2 score on training data:  0.7283114740810925
# Mean Absolute Error:  3752.902778992939
# Mean Squared Error:  31443650.420135997
# Root Mean Squared Error:  5607.46381353781

# %%
score = cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lasso)-(score.mean()))*100)
# Out:
# [0.76244813 0.70823259 0.775161   0.73289107 0.75587816]
# 0.7469221922275621
# Difference between R2 Score and Cross Validation Score:  4.93713500877202

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lasso, y= y_test, color = 'grey')
plt.plot(pred_lasso,pred_lasso,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Lasso Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### Applying Ridge Regression

# %%
rd = Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_rd))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score:  0.7961897106236729
# R2 score on training data:  0.7283106683766336
# Mean Absolute Error:  3754.683590800269
# Mean Squared Error:  31459677.636212513
# Root Mean Squared Error:  5608.892728178398

# %%
score = cross_val_score(rd,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_rd)-(score.mean()))*100)
# Out:
# [0.76244687 0.70830249 0.77506506 0.73295139 0.75584442]
# 0.7469220460352919
# Difference between R2 Score and Cross Validation Score:  4.926766458838106

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_rd, y= y_test, color = 'violet')
plt.plot(pred_lasso,pred_lasso,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Ridge Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### Applying Decision tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_dtr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score:  0.7558481139678499
# R2 score on training data:  0.9980333070000582
# Mean Absolute Error:  2732.5368655225
# Mean Squared Error:  37686711.75704093
# Root Mean Squared Error:  6138.950379099096

# %%
score = cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_dtr)-(score.mean()))*100)
# Out:
# [0.75744759 0.66544487 0.72510189 0.71776313 0.69113425]
# 0.7113783453477696
# Difference between R2 Score and Cross Validation Score:  4.446976862008034

# %% [markdown]
# #### Observation
# ##### Gradient bossting regressor is the best fit model based on the difference of both r2_score and Cross_validation_score is 4.44 and also the r2_score of test data is 89.8% and that on trainging data is 88.8 which is high and almost equal

# %% [markdown]
# ### Applying GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV
param = {'n_estimators':[100,200,300,400], 'loss':['squared_error','absolute_error','huber','quantile'],
         'learning_rate':[10,20,30],'min_samples_split':[10],'random_state':[1,4,20]}
gscv=GridSearchCV(GradientBoostingRegressor(),param,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'learning_rate': 10,
#  'loss': 'absolute_error',
#  'min_samples_split': 10,
#  'n_estimators': 100,
#  'random_state': 1}

# %%
Model = GradientBoostingRegressor(learning_rate= 10,loss= 'absolute_error',min_samples_split= 10,n_estimators= 100,random_state= 1)

# %%
Model.fit(x_train,y_train)
pred = Model.predict(x_test)
print('R2 Score: ',r2_score(y_test,pred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred))
print('Mean Squared Error: ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score:  -2.4179117835526903e+190
# Mean Absolute Error:  1.5402321594188444e+99
# Mean Squared Error:  3.732231846396788e+198
# Root Mean Squared Error:  1.931898508306476e+99

# %%
import joblib
joblib.dump(Model,'healthcare.pki')
# Out:
# ['healthcare.pki']

# %%
model = joblib.load('healthcare.pki')
prediction = model.predict(x_test)
prediction
# Out:
# array([ 1.23151792e+99,  1.23151792e+99, -9.35001411e+98,  1.23151792e+99,
#         1.23151792e+99,  1.23151792e+99,  1.23151792e+99, -4.39927041e+99,
#         1.23151792e+99, -9.35001411e+98,  1.23151792e+99,  1.23151792e+99,
#         1.23151792e+99,  1.23151792e+99, -4.39927041e+99,  1.23151792e+99,
#        -4.54492365e+98,  1.23151792e+99,  1.23151792e+99,  1.23151792e+99,
#        -9.35001411e+98,  1.23151792e+99,  1.23151792e+99, -4.39927041e+99,
#        -9.35001411e+98, -4.39927041e+99, -9.35001411e+98, -4.39927041e+99,
#        -4.39927041e+99, -9.35001411e+98, -4.39927041e+99,  1.23151792e+99,
#        -4.39927041e+99,  1.23151792e+99,  1.23151792e+99, -4.39927041e+99,
#         1.23151792e+99, -4.39927041e+99,  1.23151792e+99,  8.15768367e+97,
#         1.23151792e+99,  1.23151792e+99, -9.35001411e+98,  1.23151792e+99,
#        -9.35001411e+98,  1.23151792e+99,  1.23151792e+99, -4.54492365e+98,
# ...
