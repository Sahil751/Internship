# %% [markdown]
# ### 1) Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2) importing Dataset

# %%
df = pd.read_csv('baseball.csv',header=0,names=['WinsPitcher','Runscored','AtBat','BaseHit','2Base','3Base','HomeRuns','Baseonballs','StrikeOut','StolenBase','RunAverage','EarnedRun','EarnedRunAverage','CompleteGame','ShutOut','Save','Errors'])
df
# Out:
#     WinsPitcher  Runscored  AtBat  BaseHit  2Base  3Base  HomeRuns  \
# 0            95        724   5575     1497    300     42       139
# 1            83        696   5467     1349    277     44       156
# 2            81        669   5439     1395    303     29       141
# 3            76        622   5533     1381    260     27       136
# 4            74        689   5605     1515    289     49       151
# 5            93        891   5509     1480    308     17       232
# 6            87        764   5567     1397    272     19       212
# 7            81        713   5485     1370    246     20       217
# 8            80        644   5485     1383    278     32       167
# 9            78        748   5640     1495    294     33       161
# 10           88        751   5511     1419    279     32       172
# 11           86        729   5459     1363    278     26       230
# 12           85        661   5417     1331    243     21       176
# ...

# %% [markdown]
# ### 3) Checking few rows on random basis

# %%
df.sample(15)
# Out:
#     WinsPitcher  Runscored  AtBat  BaseHit  2Base  3Base  HomeRuns  \
# 14           68        694   5600     1405    277     46       146
# 1            83        696   5467     1349    277     44       156
# 12           85        661   5417     1331    243     21       176
# 9            78        748   5640     1495    294     33       161
# 23           67        573   5420     1361    251     18       100
# 8            80        644   5485     1383    278     32       167
# 2            81        669   5439     1395    303     29       141
# 19           64        640   5571     1382    257     27       167
# 7            81        713   5485     1370    246     20       217
# 3            76        622   5533     1381    260     27       136
# 4            74        689   5605     1515    289     49       151
# 13           76        656   5544     1379    262     22       198
# 21           83        703   5428     1363    265     13       177
# ...

# %% [markdown]
# ### 4) Checking the shape

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# #### Observation: No of rows = 30 and columns = 17

# %% [markdown]
# ### 5) Checking count of unique values

# %%
df.nunique().to_frame('No of Unique Values')
# Out:
#                   No of Unique Values
# WinsPitcher                        24
# Runscored                          28
# AtBat                              29
# BaseHit                            29
# 2Base                              22
# 3Base                              23
# HomeRuns                           27
# Baseonballs                        29
# StrikeOut                          29
# StolenBase                         27
# RunAverage                         30
# EarnedRun                          30
# EarnedRunAverage                   30
# CompleteGame                        9
# ShutOut                            12
# Save                               20
# Errors                             21

# %% [markdown]
# ### 6)Creating List of Columns in Dataset

# %%
df.columns.tolist()
# Out:
# ['WinsPitcher',
#  'Runscored',
#  'AtBat',
#  'BaseHit',
#  '2Base',
#  '3Base',
#  'HomeRuns',
#  'Baseonballs',
#  'StrikeOut',
#  'StolenBase',
#  'RunAverage',
#  'EarnedRun',
#  'EarnedRunAverage',
#  'CompleteGame',
#  'ShutOut',
#  'Save',
#  'Errors']

# %% [markdown]
# ### 7) Checking null values and also checking the same by visualization

# %%
df.isnull().sum()
# Out:
# WinsPitcher         0
# Runscored           0
# AtBat               0
# BaseHit             0
# 2Base               0
# 3Base               0
# HomeRuns            0
# Baseonballs         0
# StrikeOut           0
# StolenBase          0
# RunAverage          0
# EarnedRun           0
# EarnedRunAverage    0
# CompleteGame        0
# ShutOut             0
# Save                0
# Errors              0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation: No null values present

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   WinsPitcher       30 non-null     int64
#  1   Runscored         30 non-null     int64
#  2   AtBat             30 non-null     int64
#  3   BaseHit           30 non-null     int64
#  4   2Base             30 non-null     int64
#  5   3Base             30 non-null     int64
#  6   HomeRuns          30 non-null     int64
#  7   Baseonballs       30 non-null     int64
#  8   StrikeOut         30 non-null     int64
#  9   StolenBase        30 non-null     int64
#  10  RunAverage        30 non-null     int64
#  11  EarnedRun         30 non-null     int64
#  12  EarnedRunAverage  30 non-null     float64
#  13  CompleteGame      30 non-null     int64
#  14  ShutOut           30 non-null     int64
#  15  Save              30 non-null     int64
# ...

# %% [markdown]
# #### Observation:
# #### Except EarnedRunAverage which is float value all others are int values with memory usage 4.1kb
# #### No null values present

# %% [markdown]
# ### 8) Statistical summary of dataset

# %%
df.describe().T
# Out:
#                   count         mean         std      min        25%  \
# WinsPitcher        30.0    80.966667   10.453455    63.00    74.0000
# Runscored          30.0   688.233333   58.761754   573.00   651.2500
# AtBat              30.0  5516.266667   70.467372  5385.00  5464.0000
# BaseHit            30.0  1403.533333   57.140923  1324.00  1363.0000
# 2Base              30.0   274.733333   18.095405   236.00   262.2500
# 3Base              30.0    31.300000   10.452355    13.00    23.0000
# HomeRuns           30.0   163.633333   31.823309   100.00   140.2500
# Baseonballs        30.0   469.100000   57.053725   375.00   428.2500
# StrikeOut          30.0  1248.200000  103.759470   973.00  1157.5000
# StolenBase         30.0    83.500000   22.815225    44.00    69.0000
# RunAverage         30.0   688.233333   72.108005   525.00   636.2500
# EarnedRun          30.0   635.833333   70.140786   478.00   587.2500
# EarnedRunAverage   30.0     3.956333    0.454089     2.94     3.6825
# ...

# %% [markdown]
# #### Observation:
# #### Count of variables is same hence no null values present
# #### Mean>Median AtBat, BaseHit, HomeRuns, CompleteGame, Save, Errors are skewed towards the Right
# #### Difference in 75% and max indicates presence of outliers in Runscored, HomeRuns, BaseonBalls, StrikeOut, RunAverage, Earned Run, EarnedRunAverage, CompleteGame, Shutout,Save, Errors

# %% [markdown]
# ### 9) Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Observation: No duplicate rows

# %% [markdown]
# ### 10) Heatmap

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth =0.2, linecolor='grey',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Feature_Name',fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %% [markdown]
# ### 11) Univariate Analysis using distplot

# %%
plt.figure(figsize=(10,20),facecolor = 'grey')
plotnumber = 1
for i in df:
    if plotnumber<=18:
        ax=plt.subplot(5,4,plotnumber)
        sns.distplot(df[i],color='g')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### Observation:
# #### WnsPitcher,Runscored,2Base,3Base,StolenBase, EarnedRunsAverage are near to normal distribution
# #### AtBat, BaseHit, HomeRuns, CompleteGame, Save, Errors are skewed towards the Right
# #### Others are skewed towards left

# %% [markdown]
# ### 12) Bivariate Analysis

# %% [markdown]
# ### a) WinsPitcher with others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='WinsPitcher',y = i,data=df,color='b')
        plt.xlabel('WinsPitcher')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation:
# #### a)EarnedRunsAverage,EarnedRuns,Run Average have -ve relation with Winspitcher
# #### b) Slightly Positive relation between WinsPitcher and Save

# %% [markdown]
# ### b) Runscored with others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='Runscored',y = i,data=df,color='r')
        plt.xlabel('Runscored')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: Runscored has slight positive corelation with AtBat, Baseonball, HomeRuns

# %% [markdown]
# ### c) Relation between AtBat and others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='AtBat',y = i,data=df,color='g')
        plt.xlabel('AtBat')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: AtBat has no relation with others

# %% [markdown]
# #### c) Realtion between BaseHit and others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='BaseHit',y = i,data=df,color='g')
        plt.xlabel('BaseHit')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Obseravtion: No relation between BaseHit and others

# %% [markdown]
# ### d) Relation Between 2Base and others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='2Base',y = i,data=df,color='g')
        plt.xlabel('2Base')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: No relation

# %% [markdown]
# ### e) Relation Between 3 Base and others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='3Base',y = i,data=df,color='g')
        plt.xlabel('3Base')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: No relation

# %% [markdown]
# ### f) Relation between HomeRuns

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='HomeRuns',y = i,data=df,color='g')
        plt.xlabel('HomeRuns')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: Relation between HomeRuns and Runscored

# %% [markdown]
# ### g) Relation between BaseonBalls

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='Baseonballs',y = i,data=df,color='g')
        plt.xlabel('Baseonballs')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: No relation

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='StrikeOut',y = i,data=df,color='g')
        plt.xlabel('StrikeOut')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Observation: No relation between StrikeOut and Others

# %%
plt.figure(figsize=(20,30))
pltno = 1
for i in df:
    if pltno <= 17:
        plt.subplot(5,4,pltno)
        sns.scatterplot(x='StolenBase',y = i,data=df,color='g')
        plt.xlabel('StolenBase')
        plt.ylabel(i)
    pltno+=1
plt.show()

# %% [markdown]
# #### Obsevation: No relation between StolenBase and Others

# %%
sns.pairplot(data=df,palette='colorblind')

# %% [markdown]
# #### Observationbaring a few no significant relation between variables

# %% [markdown]
# ### 13) Checking Outliers

# %%
plt.figure(figsize=(20,40),facecolor='grey')
pltno = 1
for i in df:
    if pltno<=18:
        ax=plt.subplot(8,4,pltno)
        sns.boxplot(df[i],palette='gnuplot')
        plt.xlabel(i,fontsize=15)
        plt.yticks(rotation = 0,fontsize=10)
    pltno+=1
plt.tight_layout()

# %% [markdown]
# #### Observation: Outlier present in Errors, Save, ShutOut, EarnedRunAverage, Runscored

# %%
from scipy.stats import zscore
out_feature = df[['Errors','Save','ShutOut','EarnedRunAverage','Runscored']]
z = np.abs(zscore(out_feature))
z
# Out:
#       Errors      Save   ShutOut  EarnedRunAverage  Runscored
# 0   0.461470  1.671607  0.814629          0.506955   0.619078
# 1   0.607197  0.249879  0.172800          0.254598   0.134432
# 2   1.117242  0.654856  0.320914          0.641347   0.332906
# 3   0.485758  0.784104  0.567771          0.053010   1.146419
# 4   0.607197  1.042600  0.172800          1.531318   0.013270
# 5   0.461470  1.171848  0.320914          0.350165   3.509647
# 6   0.097152  0.637623  1.802057          0.165003   1.311430
# 7   1.262970  0.008617  0.320914          0.209800   0.428681
# 8   0.048576  2.188598  0.172800          0.484557   0.765626
# 9   0.194303  0.396360  0.320914          0.792164   1.034489
# 10  1.797303  0.249879  0.567771          0.635374   1.086415
# 11  0.680061  0.525608  0.419657          0.865333   0.705622
# 12  0.097152  0.379127  0.172800          0.036584   0.471376
# 13  0.024288  0.249879  0.172800          0.456185   0.557920
# ...

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([4], dtype=int64))

# %%
df1 = df[(z<3).all(axis=1)]

# %%
df1
# Out:
#     WinsPitcher  Runscored  AtBat  BaseHit  2Base  3Base  HomeRuns  \
# 0            95        724   5575     1497    300     42       139
# 1            83        696   5467     1349    277     44       156
# 2            81        669   5439     1395    303     29       141
# 3            76        622   5533     1381    260     27       136
# 4            74        689   5605     1515    289     49       151
# 6            87        764   5567     1397    272     19       212
# 7            81        713   5485     1370    246     20       217
# 8            80        644   5485     1383    278     32       167
# 9            78        748   5640     1495    294     33       161
# 10           88        751   5511     1419    279     32       172
# 11           86        729   5459     1363    278     26       230
# 12           85        661   5417     1331    243     21       176
# 13           76        656   5544     1379    262     22       198
# ...

# %%
df1.shape
# Out:
# (29, 17)

# %%
df1.skew()
# Out:
# WinsPitcher         0.119013
# Runscored          -0.215364
# AtBat               0.169573
# BaseHit             0.783772
# 2Base              -0.335304
# 3Base               0.090124
# HomeRuns            0.450862
# Baseonballs         0.151193
# StrikeOut          -0.233815
# StolenBase          0.494966
# RunAverage          0.018155
# EarnedRun           0.018461
# EarnedRunAverage    0.016693
# CompleteGame        0.854980
# ShutOut             0.526943
# Save                0.627480
# Errors              0.840271
# dtype: float64

# %%
df1['Runscored']=np.cbrt(df['Runscored'])
df1['BaseHit']=np.cbrt(df['BaseHit'])
df1['CompleteGame']=np.cbrt(df['CompleteGame'])
df1['Save']=np.cbrt(df['Save'])
df1['Errors']=np.cbrt(df['Errors'])

# %%
plt.figure(figsize=(10,20),facecolor = 'grey')
plotnumber = 1
for i in df1:
    if plotnumber<=18:
        ax=plt.subplot(5,4,plotnumber)
        sns.distplot(df1[i],color='g')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### 14) Corelation between feature and label

# %%
df1.corr()
# Out:
#                   WinsPitcher  Runscored     AtBat   BaseHit     2Base  \
# WinsPitcher          1.000000   0.396810 -0.085780 -0.019968  0.384886
# Runscored            0.396810   1.000000  0.437170  0.429012  0.475067
# AtBat               -0.085780   0.437170  1.000000  0.769847  0.490752
# BaseHit             -0.019968   0.429012  0.769847  1.000000  0.527588
# 2Base                0.384886   0.475067  0.490752  0.527588  1.000000
# 3Base               -0.206737   0.139017  0.445604  0.580521  0.342419
# HomeRuns             0.245697   0.590464 -0.064653 -0.219048 -0.098695
# Baseonballs          0.447513   0.259217 -0.137850 -0.221951  0.211243
# StrikeOut            0.156469   0.090591 -0.111243 -0.372834 -0.096772
# StolenBase          -0.169503   0.074056  0.373674  0.419443  0.194308
# RunAverage          -0.823176  -0.023950  0.315499  0.243965 -0.215196
# EarnedRun           -0.815308  -0.002549  0.309146  0.280165 -0.224993
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),fmt = '0.2f',linewidth=0.2,linecolor='black',annot=True,cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %% [markdown]
# #### Observation:
# #### Strong correaltion between RunAverage and Winspitcher,EarnedRuns and Winspitcher, EarnedRunAverage and winspitcher, RunAverage and ShutOut,RunAverage and Save, RunAverage and EarnedRunAverage,

# %% [markdown]
# ### 15) Separating Independent and Dependent variable

# %%
x = df1.drop('WinsPitcher',axis=1)
y = df1['WinsPitcher']

# %%
x
# Out:
#     Runscored  AtBat    BaseHit  2Base  3Base  HomeRuns  Baseonballs  \
# 0    8.979377   5575  11.439506    300     42       139          383
# 1    8.862095   5467  11.049365    277     44       156          439
# 2    8.745985   5439  11.173556    303     29       141          533
# 3    8.536178   5533  11.136051    260     27       136          404
# 4    8.832285   5605  11.485173    289     49       151          455
# 6    9.141787   5567  11.178893    272     19       212          554
# 7    8.933669   5485  11.106405    246     20       217          418
# 8    8.635655   5485  11.141425    278     32       167          436
# 9    9.077520   5640  11.434409    294     33       161          478
# 10   9.089639   5511  11.237270    279     32       172          503
# 11   9.000000   5459  11.087457    278     26       230          486
# 12   8.710983   5417  11.000000    243     21       176          435
# 13   8.688963   5544  11.130673    262     22       198          478
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: WinsPitcher, dtype: int64

# %% [markdown]
# ### 16) Scaling data using standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#     Runscored     AtBat   BaseHit     2Base     3Base  HomeRuns  Baseonballs  \
# 0    0.955349  0.830084  1.728647  1.556538  1.010845 -0.765863    -1.536359
# 1    0.348400 -0.702831 -0.946162  0.201171  1.208917 -0.181389    -0.495021
# 2   -0.252490 -1.100253 -0.094708  1.733325 -0.276617 -0.697101     1.252941
# 3   -1.338270  0.233951 -0.351839 -0.800621 -0.474688 -0.869006    -1.145857
# 4    0.194128  1.255894  2.041742  0.908319  1.704094 -0.353293    -0.197495
# 5    1.795850  0.716535 -0.058116 -0.093474 -1.266972  1.743939     1.643442
# 6    0.718804 -0.447345 -0.555092 -1.625627 -1.167936  1.915843    -0.885522
# 7   -0.823461 -0.447345 -0.315000  0.260100  0.020490  0.196801    -0.550807
# 8    1.463254  1.752672  1.693704  1.202964  0.119526 -0.009484     0.230197
# 9    1.525975 -0.078310  0.342114  0.319029  0.020490  0.368705     0.695081
# 10   1.062078 -0.816380 -0.685001  0.260100 -0.573723  2.362794     0.378960
# ...

# %% [markdown]
# ### 17) Checking Variance Inflation Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#      VIF Values          Features
# 0      7.155422         Runscored
# 1     16.747702             AtBat
# 2      8.795669           BaseHit
# 3      3.993353             2Base
# 4      3.348669             3Base
# 5      8.701944          HomeRuns
# 6      3.579244       Baseonballs
# 7      2.894199         StrikeOut
# 8      1.972783        StolenBase
# 9    199.551417        RunAverage
# 10  1818.440167         EarnedRun
# 11  1412.156071  EarnedRunAverage
# 12     2.757167      CompleteGame
# 13     3.615338           ShutOut
# 14     4.611969              Save
# 15     2.114972            Errors

# %%
x.drop('EarnedRun',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Values          Features
# 0     6.317876         Runscored
# 1     7.194716             AtBat
# 2     8.496920           BaseHit
# 3     3.713096             2Base
# 4     3.313451             3Base
# 5     7.576257          HomeRuns
# 6     3.579176       Baseonballs
# 7     2.885960         StrikeOut
# 8     1.843390        StolenBase
# 9   145.946169        RunAverage
# 10  143.821432  EarnedRunAverage
# 11    2.524181      CompleteGame
# 12    3.480914           ShutOut
# 13    2.331835              Save
# 14    2.067460            Errors

# %%
x.drop('RunAverage',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Values          Features
# 0     6.310300         Runscored
# 1     4.477251             AtBat
# 2     7.225711           BaseHit
# 3     3.698495             2Base
# 4     3.275544             3Base
# 5     6.426594          HomeRuns
# 6     3.200306       Baseonballs
# 7     2.303499         StrikeOut
# 8     1.788584        StolenBase
# 9     5.380061  EarnedRunAverage
# 10    2.518244      CompleteGame
# 11    3.253949           ShutOut
# 12    2.242184              Save
# 13    2.019203            Errors

# %% [markdown]
# ### 18) Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as knn
from sklearn.model_selection import cross_val_score

# %%
maxAcc = 0
maxRs = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc > maxAcc:
        maxAcc = acc
        maxRs= i
print('Max r2 score is: ',maxAcc, 'on Random State', maxRs)
# Out:
# Max r2 score is:  0.9441855199036521 on Random State 75

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20,random_state=maxRs)

# %% [markdown]
# ### a) Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
pred_lr = lr.predict(x_test)
pred_train = lr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2_score:  0.9441855199036521
# R2 score on training data:  0.9172246834264064
# Mean Absolute Error:  2.1821398514799717
# Mean Squared Error:  7.542706824131465
# Root Mean Squared Error:  2.7463988829249595

# %%
score = cross_val_score(lr,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lr)-(score.mean()))*100)
# Out:
# [ 0.34747462 -0.88850398  0.61663623  0.49587356  0.66174512]
# 0.24664511119829252
# Difference between R2 Score and Cross Validation Score:  69.75404087053596

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lr, y= y_test, color = 'b')
plt.plot(pred_lr,pred_lr,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Linear Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### b) Random Forest Regressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_RFR))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score:  0.6883049948612538
# R2 score on training data:  0.9343298034117322
# Mean Absolute Error:  5.3549999999999995
# Mean Squared Error:  42.12211666666666
# Root Mean Squared Error:  6.490155365371977

# %%
score = cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_RFR)-(score.mean()))*100)
# Out:
# [ 0.38043659 -4.55323289  0.42331384  0.39517295  0.80106397]
# -0.5106491070742759
# Difference between R2 Score and Cross Validation Score:  119.89541019355299

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_RFR, y= y_test, color = 'b')
plt.plot(pred_RFR,pred_RFR,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Random Forest Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### c) Kneighbour Regressor

# %%
KNN = knn()
KNN.fit(x_train, y_train)
pred_KNN = KNN.predict(x_test)
pred_train = KNN.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_KNN))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_KNN))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_KNN))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# R2_score:  0.7102240493319631
# R2 score on training data:  0.5057306070992396
# Mean Absolute Error:  5.333333333333333
# Mean Squared Error:  39.15999999999999
# Root Mean Squared Error:  6.257795138864806

# %%
score = cross_val_score(KNN,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_KNN)-(score.mean()))*100)
# Out:
# [ 0.1435     -2.15842105  0.4126307   0.29154098  0.77216981]
# -0.10771591185034687
# Difference between R2 Score and Cross Validation Score:  81.79399611823101

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_KNN, y= y_test, color = 'b')
plt.plot(pred_KNN,pred_KNN,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('KNeighbors Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### d) Gradient Boosting Regressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_gbr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_gbr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_gbr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# R2_score:  0.5901371937051667
# R2 score on training data:  0.9999997901459842
# Mean Absolute Error:  6.660923486961164
# Mean Squared Error:  55.388404239565666
# Root Mean Squared Error:  7.442338627042287

# %%
score = cross_val_score(gbr,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_gbr)-(score.mean()))*100)
# Out:
# [ 0.13109592 -7.75490653  0.47033488  0.48679615  0.7704869 ]
# -1.1792385364083853
# Difference between R2 Score and Cross Validation Score:  176.9375730113552

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_gbr, y= y_test, color = 'grey')
plt.plot(pred_gbr,pred_gbr,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Gradient Boosting Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### e) Lasso Regression

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lasso))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score:  0.9254132229895109
# R2 score on training data:  0.8662358758984644
# Mean Absolute Error:  2.684785437003164
# Mean Squared Error:  10.079574171000818
# Root Mean Squared Error:  3.1748345108053773

# %%
score = cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lasso)-(score.mean()))*100)
# Out:
# [ 0.74398957 -0.82390805  0.77801894  0.79050307  0.87869459]
# 0.4734596224961079
# Difference between R2 Score and Cross Validation Score:  45.1953600493403

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lasso, y= y_test, color = 'grey')
plt.plot(pred_lasso,pred_lasso,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Lasso Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### f) Ridge Regression

# %%
rd = Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_rd))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score:  0.9336765461631826
# R2 score on training data:  0.9128868550311882
# Mean Absolute Error:  2.378981814787297
# Mean Squared Error:  8.962877858781011
# Root Mean Squared Error:  2.9938065833952954

# %%
score = cross_val_score(rd,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_rd)-(score.mean()))*100)
# Out:
# [ 0.44084287 -1.05104817  0.65764883  0.88702997  0.82532646]
# 0.35195999339551665
# Difference between R2 Score and Cross Validation Score:  58.1716552767666

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_rd, y= y_test, color = 'violet')
plt.plot(pred_rd,pred_rd,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Ridge Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### g) Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_dtr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score:  0.488180883864337
# R2 score on training data:  1.0
# Mean Absolute Error:  7.5
# Mean Squared Error:  69.16666666666667
# Root Mean Squared Error:  8.3166499665831

# %%
score = cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_dtr)-(score.mean()))*100)
# Out:
# [ -1.66931818 -10.26315789   0.13174404   0.17540984  -0.60966981]
# -2.4469984023319276
# Difference between R2 Score and Cross Validation Score:  293.51792861962645

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_dtr, y= y_test, color = 'violet')
plt.plot(pred_dtr,pred_dtr,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('DecisionTreeRegressor', fontsize = 14)
plt.show()

# %% [markdown]
# #### Observation: Since the amount of data is very less hence the nodel is not able to be trained propoerly. As per the data available the best modelling technique would be lasso regression with R2 score 0.92 and difference between R2score and Cross Validation Score as 45.

# %% [markdown]
# ### Applying Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV
param = {'fit_intercept':[True,False],'copy_X':[True,False],'max_iter':[100,200,500,1000],
        'random_state':[1,4,20],'positive':[True,False],'selection':['cyclic', 'random']}
gscv=GridSearchCV(Lasso(),param,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 100,
#  'positive': False,
#  'random_state': 1,
#  'selection': 'random'}

# %%
Model = Lasso(copy_X= True,
 fit_intercept= True,
 max_iter = 100,
 positive = False,
 random_state = 1,
 selection= 'random')

# %%
Model.fit(x_train,y_train)
pred = Model.predict(x_test)
print('R2 Score: ',r2_score(y_test,pred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred))
print('Mean Squared Error: ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score:  0.9254073912056626
# Mean Absolute Error:  2.685032402684603
# Mean Squared Error:  10.08036227179032
# Root Mean Squared Error:  3.174958625209204

# %%
import joblib
joblib.dump(Model,'baseball.pki')
# Out:
# ['baseball.pki']

# %%
model = joblib.load('baseball.pki')
prediction = model.predict(x_test)
prediction
# Out:
# array([81.16944837, 72.31967028, 73.83400868, 85.69673712, 70.15298929,
#        96.662271  ])

# %%
conclusion = pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])

# %%
conclusion
# Out:
#                    0         1          2          3          4           5
# Predicted  81.169448  72.31967  73.834009  85.696737  70.152989   96.662271
# Original   83.000000  71.00000  76.000000  87.000000  64.000000  100.000000
