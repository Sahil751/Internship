# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Importing Data

# %%
df = pd.read_csv('temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# #### Observation: No of rows = 7752, columns = 25

# %% [markdown]
# ### Checking data on random basis

# %%
df.sample(15)
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 1365     16.0  23-08-2013          27.1          21.8    37.124859
# 3199     25.0  03-07-2015          27.8          20.6    33.281219
# 5542     18.0  04-08-2016          37.2          26.8    42.619946
# 314      15.0  12-07-2013          23.7          22.9    92.779335
# 3697     23.0  23-07-2015          31.3          25.2    81.797569
# 391      17.0  15-07-2013          28.9          22.8    79.157448
# 1653      4.0  04-07-2014          31.6          21.6    49.419498
# 1814     15.0  10-07-2014          33.1          23.9    40.603157
# 148      24.0  05-07-2013          31.1          22.2    56.545139
# 4737     13.0  03-07-2016          26.7          21.9    62.518356
# 1069     20.0  11-08-2013          33.6          24.1    52.907932
# 302       3.0  12-07-2013          24.7          23.1    91.112747
# 7727      3.0  30-08-2017          23.0          17.0    26.563343
# ...

# %% [markdown]
# ### Checking Count of Unique values

# %%
df.nunique().to_frame('No of Unique Values')
# Out:
#                   No of Unique Values
# station                            25
# Date                              310
# Present_Tmax                      167
# Present_Tmin                      155
# LDAPS_RHmin                      7672
# LDAPS_RHmax                      7664
# LDAPS_Tmax_lapse                 7675
# LDAPS_Tmin_lapse                 7675
# LDAPS_WS                         7675
# LDAPS_LH                         7675
# LDAPS_CC1                        7569
# LDAPS_CC2                        7582
# LDAPS_CC3                        7599
# LDAPS_CC4                        7524
# LDAPS_PPT1                       2812
# LDAPS_PPT2                       2510
# LDAPS_PPT3                       2356
# LDAPS_PPT4                       1918
# lat                                12
# lon                                25
# DEM                                25
# Slope                              27
# Solar radiation                  1575
# Next_Tmax                         183
# ...

# %% [markdown]
# ### Creating list of columns

# %%
df.columns.tolist()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %% [markdown]
# ### Checking Null Values

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation: Except lat, lon, den, slope, solar radiation all have null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %% [markdown]
# #### Observation: Except Date which is of object datatype all others are float

# %% [markdown]
# ### Checking statistical data

# %%
df.describe().T
# Out:
#                    count         mean         std          min          25%  \
# station           7750.0    13.000000    7.211568     1.000000     7.000000
# Present_Tmax      7682.0    29.768211    2.969999    20.000000    27.800000
# Present_Tmin      7682.0    23.225059    2.413961    11.300000    21.700000
# LDAPS_RHmin       7677.0    56.759372   14.668111    19.794666    45.963543
# LDAPS_RHmax       7677.0    88.374804    7.192004    58.936283    84.222862
# LDAPS_Tmax_lapse  7677.0    29.613447    2.947191    17.624954    27.673499
# LDAPS_Tmin_lapse  7677.0    23.512589    2.345347    14.272646    22.089739
# LDAPS_WS          7677.0     7.097875    2.183836     2.882580     5.678705
# LDAPS_LH          7677.0    62.505019   33.730589   -13.603212    37.266753
# LDAPS_CC1         7677.0     0.368774    0.262458     0.000000     0.146654
# LDAPS_CC2         7677.0     0.356080    0.258061     0.000000     0.140615
# ...

# %% [markdown]
# #### Observation:
# #### a) Count is different which indicates presence of null values
# #### b) Mean = Median in station
# #### c) Minor difference between Mean and Median in Present_Tmax, Present_Tmin, LDAPS_RHmin, LDAPS_RHmax, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse, lat, lon, Next_Tmax, hence data will have skewness but very very low
# #### d) Difference between Mean and Median is high in case of LDAPS_WS, LDAPS_LH, LDAPS_CC1, LDAPS_CC2, LDAPS_CC4, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4,DEM, Slope, Solar Radiation, Next_Tmin

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth =0.2, linecolor='grey',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Feature_Name',fontsize=14)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %% [markdown]
# ### Checking Duplicate Values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Separating Numerical and Categorical Column

# %%
cat_col = []
for i in df.dtypes.index:
    if df.dtypes[i] == 'object':
        cat_col.append(i)
print('Categorical Columns: ', cat_col)
print('\n')
# Out:
# Categorical Columns:  ['Date']

# %%
num_col = []
for i in df.dtypes.index:
    if df.dtypes[i] != 'object':
        num_col.append(i)
print('Numerical Columns: ', num_col)
print('\n')
# Out:
# Numerical Columns:  ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin']

# %% [markdown]
# ### Univariate Analysis Using Displot

# %%
plt.figure(figsize=(10,20),facecolor = 'grey')
plotnumber = 1
for i in num_col:
    if plotnumber<=25:
        ax=plt.subplot(5,5,plotnumber)
        sns.distplot(df[i],color='g')
        plt.xlabel(i,fontsize=12)
        plt.yticks(rotation=0,fontsize = 10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### Observations
# #### 1) Present_Tmax , Present_Tmin, LDAPS_Tmax_lapse are almost normally distributed
# #### 2) RHmax, LDAPS_Tmin_lapse, solar_radiation is left skewed
# #### 3) RHmin,LDAPS_WS, LDAPS_LH, LDAPS_CC1, LDAPS_CC2, LDAPS_CC3,LDAPS_CC4, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4 is right skewed
# #### 4) Majority of data for LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4 lies at 0

# %%
ax = sns.countplot(x='station',data=df)
plt.xticks(rotation=90)
print(df['station'].value_counts())
plt.show()
# Out:
# 1.0     310
# 14.0    310
# 24.0    310
# 23.0    310
# 22.0    310
# 21.0    310
# 20.0    310
# 19.0    310
# 18.0    310
# 17.0    310
# 16.0    310
# 15.0    310
# 13.0    310
# 2.0     310
# 12.0    310
# 11.0    310
# 10.0    310
# 9.0     310
# 8.0     310
# 7.0     310
# 6.0     310
# 5.0     310
# 4.0     310
# 3.0     310
# 25.0    310
# Name: station, dtype: int64

# %% [markdown]
# #### Observation:- All values of station have equal count of 310

# %%
ax = sns.countplot(x='Slope',data=df)
plt.xticks(rotation=90)
print(df['Slope'].value_counts())
plt.show()
# Out:
# 2.785000    310
# 0.514100    310
# 0.271300    310
# 0.222300    310
# 0.155400    310
# 0.133200    310
# 0.572100    310
# 4.729600    310
# 1.767800    310
# 1.231300    310
# 0.697000    310
# 2.257900    310
# 0.855200    310
# 0.618000    310
# 2.686500    310
# 0.593100    310
# 0.623300    310
# 5.178200    310
# 0.412500    310
# 1.562900    310
# 0.098500    310
# 0.145700    310
# 0.505500    310
# 2.534800    310
# 0.266100    310
# 0.098475      1
# 5.178230      1
# Name: Slope, dtype: int64

# %% [markdown]
# #### Observation: Except for values 0.98475 and 5.178230 all others have equalu count of 310. This is becoz others values are upto 4 decimal places whereas 0.98475 and 5.178230 are upto 6 and 5 decimal palces

# %% [markdown]
# ### Rounding 2 values of slope

# %%
df['Slope'].replace({0.0984746:0.0985,5.17823:5.1782},inplace=True)

# %%
ax = sns.countplot(x='DEM',data=df)
plt.xticks(rotation=90)
print(df['DEM'].value_counts())
plt.show()
# Out:
# 212.3350    311
# 12.3700     311
# 30.9680     310
# 17.2956     310
# 15.5876     310
# 21.9668     310
# 26.2980     310
# 146.5540    310
# 75.0924     310
# 56.4448     310
# 53.4712     310
# 82.2912     310
# 30.0464     310
# 59.8324     310
# 44.7624     310
# 132.1180    310
# 28.7000     310
# 208.5070    310
# 50.9312     310
# 52.5180     310
# 54.6384     310
# 35.0380     310
# 45.7160     310
# 33.3068     310
# 19.5844     310
# Name: DEM, dtype: int64

# %% [markdown]
# #### Observation: Except for 2 values 12.37 and 212.335 which have count of 311, all other values have count of 310

# %%
ax = sns.countplot(x='lat',data=df)
plt.xticks(rotation=90)
print(df['lat'].value_counts())
plt.show()
# Out:
# 37.5776    1240
# 37.5507    1240
# 37.6046     620
# 37.5102     620
# 37.4697     620
# 37.4967     620
# 37.5372     620
# 37.6181     620
# 37.5237     620
# 37.6450     311
# 37.4562     311
# 37.4832     310
# Name: lat, dtype: int64

# %% [markdown]
# #### Observation: Values 37.5507 and 37.5776 have highest count of 1240. There are 7 values which have count of 320, 2 values with count of 311 and one value with count of 310

# %%
ax = sns.countplot(x='lon',data=df)
plt.xticks(rotation=90)
print(df['lon'].value_counts())
plt.show()
# Out:
# 127.135    311
# 126.826    311
# 126.991    310
# 126.937    310
# 126.909    310
# 126.891    310
# 127.086    310
# 127.040    310
# 127.004    310
# 126.938    310
# 127.024    310
# 127.099    310
# 126.995    310
# 127.083    310
# 126.927    310
# 127.032    310
# 126.988    310
# 127.085    310
# 126.955    310
# 126.910    310
# 126.838    310
# 127.042    310
# 127.022    310
# 127.058    310
# 126.970    310
# Name: lon, dtype: int64

# %% [markdown]
# Observation: Except 126.826 and 127.135 which have count of 311 all others in lon have count of 310

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Temperature Vs Present day Temperature')

plt.subplot(2,2,1)
plt.title('Next day max Temperature Vs Present day max Temperature')
sns.regplot(x='Present_Tmax',y='Next_Tmax',data=df,color='g')

plt.subplot(2,2,2)
plt.title('Next day max Temperature Vs Present day min Temperature')
sns.regplot(x='Present_Tmin',y='Next_Tmax',data=df,color='b')

plt.subplot(2,2,3)
plt.title('Next day min Temperature Vs Present day max Temperature')
sns.regplot(x='Present_Tmax',y='Next_Tmin',data=df,color='y')

plt.subplot(2,2,4)
plt.title('Next day min Temperature Vs Present day min Temperature')
sns.regplot(x='Present_Tmin',y='Next_Tmin',data=df,color='r')
# Out:
# <AxesSubplot:title={'center':'Next day min Temperature Vs Present day min Temperature'}, xlabel='Present_Tmin', ylabel='Next_Tmin'>

# %% [markdown]
# #### Observation: Clearly indicates strong positive corelation between Present Day and Next Day Temperature

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Temperatures Vs Present day Relative Humidity')

plt.subplot(2,2,1)
plt.title('Next day max Temperatures Vs Present day max Relative Humidity')
sns.scatterplot(x='LDAPS_RHmax',y='Next_Tmax',data=df,color='c')

plt.subplot(2,2,2)
plt.title('Next day max Temperatures Vs Present day min Relative Humidity')
sns.scatterplot(x='LDAPS_RHmin',y='Next_Tmax',data=df,color='c')

plt.subplot(2,2,3)
plt.title('Next day min Temperatures Vs Present day max Relative Humidity')
sns.scatterplot(x='LDAPS_RHmax',y='Next_Tmin',data=df,color='c')

plt.subplot(2,2,4)
plt.title('Next day min Temperatures Vs Present day min Relative Humidity')
sns.scatterplot(x='LDAPS_RHmin',y='Next_Tmin',data=df,color='c')
# Out:
# <AxesSubplot:title={'center':'Next day min Temperatures Vs Present day min Relative Humidity'}, xlabel='LDAPS_RHmin', ylabel='Next_Tmin'>

# %% [markdown]
# #### Observation: Next_Tmax shows a downward tread against LDAPS_RHmax and LDAPS_RHmin

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Temperatures Vs Present day Temperature applied lapse rate')

plt.subplot(2,2,1)
sns.scatterplot(x='LDAPS_Tmax_lapse',y='Next_Tmax',data=df,color='c')

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_Tmin_lapse',y='Next_Tmax',data=df,color='g')

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_Tmax_lapse',y='Next_Tmin',data=df,color='y')

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_Tmin_lapse',y='Next_Tmin',data=df,color='b')
# Out:
# <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmin'>

# %% [markdown]
# #### Observation: There is high positive correlation of Next day temperatures with the present day temperatures applied lapse rate

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Maximum Temperature Vs Next day average Cloud Cover')

plt.subplot(2,2,1)
sns.scatterplot(x='LDAPS_CC1',y='Next_Tmax',data=df,palette='Dark2')

plt.subplot(2,2,2)
sns.scatterplot(x='LDAPS_CC2',y='Next_Tmax',data=df,palette='bright')

plt.subplot(2,2,3)
sns.scatterplot(x='LDAPS_CC3',y='Next_Tmax',data=df,palette='twilight')

plt.subplot(2,2,4)
sns.scatterplot(x='LDAPS_CC4',y='Next_Tmax',data=df,palette='winter_r')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmax'>

# %% [markdown]
# #### Observation: Tmax decreases as the cloud cover increases

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Minium Temperature Vs Next day average Cloud Cover')

plt.subplot(2,2,1)
sns.scatterplot(x='LDAPS_CC1',y='Next_Tmin',data=df,palette='Dark2')

plt.subplot(2,2,2)
sns.scatterplot(x='LDAPS_CC2',y='Next_Tmin',data=df,palette='bright')

plt.subplot(2,2,3)
sns.scatterplot(x='LDAPS_CC3',y='Next_Tmin',data=df,palette='twilight')

plt.subplot(2,2,4)
sns.scatterplot(x='LDAPS_CC4',y='Next_Tmin',data=df,palette='winter_r')
# Out:
# <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmin'>

# %% [markdown]
# ### Observation: Tmin seems to remain unaffeact by cloud cover

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Maximum Temperature Vs Next day average Precipitation')

plt.subplot(2,2,1)
sns.regplot(x='LDAPS_PPT1',y='Next_Tmax',data=df,color='g')

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_PPT2',y='Next_Tmax',data=df,color='b')

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_PPT3',y='Next_Tmax',data=df,color='y')

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_PPT4',y='Next_Tmax',data=df,color='r')
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmax'>

# %% [markdown]
# #### Observation: Tmax decreases as the precipitation increases

# %%
plt.figure(figsize=(15,12))
plt.suptitle('Next day Minimum Temperature Vs Next day average Precipitation')

plt.subplot(2,2,1)
sns.regplot(x='LDAPS_PPT1',y='Next_Tmin',data=df)

plt.subplot(2,2,2)
sns.regplot(x='LDAPS_PPT2',y='Next_Tmin',data=df)

plt.subplot(2,2,3)
sns.regplot(x='LDAPS_PPT3',y='Next_Tmin',data=df)

plt.subplot(2,2,4)
sns.regplot(x='LDAPS_PPT4',y='Next_Tmin',data=df)
# Out:
# <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmin'>

# %% [markdown]
# #### Observation: There is very slight change on increase of precipitation in Tmin

# %%
plt.figure(figsize=(15,6))
plt.suptitle('Next day Temperatures Vs Next day average Wind Speed')

plt.subplot(1,2,1)
sns.regplot(x='LDAPS_WS',y='Next_Tmax',data=df,color='y')

plt.subplot(1,2,2)
sns.regplot(x='LDAPS_WS',y='Next_Tmin',data=df,color='y')
# Out:
# <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmin'>

# %% [markdown]
# #### Observation: Temperarue decreases as the wind speed increases. Effect on Tmax is >> Tmin

# %%
plt.figure(figsize=(15,6))
plt.suptitle('Next day Temperatures Vs Next day average latent heat flux')

plt.subplot(1,2,1)
sns.regplot(x='LDAPS_LH',y='Next_Tmax',data=df,color='k')

plt.subplot(1,2,2)
sns.regplot(x='LDAPS_LH',y='Next_Tmin',data=df,color='k')
# Out:
# <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmin'>

# %% [markdown]
# #### Observation: As LDAPS_LH increases Tmax also increases while Tmin decreases

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,cmap='Greys')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observation: Strong correlation of Next day Tmax and Tmin with Present day Tmax and Tmin, Tmax applied lapse rate and Tmin applied lapse rate. Strong negative correlation of Tmax with cloud cover splits and relative minimum humidity.  High correlation between many independent features such as Present Day Tmax and Tmin, elevation ans slope etc. Multicollinearity need to be eliminated.

# %% [markdown]
# ### Dropping Null values

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7588, 25)

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df.drop('Date',axis=1,inplace=True)

# %% [markdown]
# ### Checking Outliers

# %%
plt.figure(figsize=(20,25))
p=1
for i in num_col:
    if p<24:
        plt.subplot(5,5,p)
        sns.boxplot(df[i],palette='Set2_r')
        plt.xlabel(i)
    p+=1
plt.show()

# %%
from scipy.stats import zscore
out_feat = df[['Present_Tmax', 'Present_Tmin', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'DEM', 'Slope']]
z = np.abs(zscore(out_feat))
z
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0         0.353318      0.748029     0.382768          0.525269
# 1         0.725138      0.664721     0.311697          0.078334
# 2         0.624033      0.043400     0.609425          0.160080
# 3         0.758840      0.085054     1.128335          0.028710
# 4         0.556630      0.539758     0.249244          0.171981
# ...            ...           ...          ...               ...
# 7745      2.240616      2.247578     1.402898          0.614083
# 7746      2.442826      2.414195     0.648815          0.990460
# 7747      2.173212      2.539157     1.318376          1.110333
# 7748      2.173212      2.289232     1.537141          0.886737
# 7749      2.206914      2.414195     1.544257          0.570995
#
#       LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_PPT1  LDAPS_PPT2  \
# 0             0.215525  0.126423  0.206603    0.305589    0.275777
# ...

# %%
np.where(z>3)
# Out:
# (array([  25,   25,   26, ..., 7581, 7582, 7582], dtype=int64),
#  array([5, 8, 8, ..., 1, 1, 4], dtype=int64))

# %%
df1 = df[(z<3).all(axis=1)]
df1.shape
# Out:
# (6752, 24)

# %%
Data_lost_Per = ((df.shape[0]-df1.shape[0])/df.shape[0]*100)

# %%
Data_lost_Per
# Out:
# 11.017395888244597

# %% [markdown]
# ### Checking Skewness

# %%
df.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            1.553926
# LDAPS_LH            0.662971
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.639649
# LDAPS_CC4           0.663815
# LDAPS_PPT1          5.305906
# LDAPS_PPT2          5.710360
# LDAPS_PPT3          6.356670
# LDAPS_PPT4          6.681256
# lat                 0.085377
# lon                -0.289048
# DEM                 1.721617
# Slope               1.559050
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
for i in num_col:
    if np.abs(df[i].skew())>=0.5:
        df[i]=pt.fit_transform(df[i].values.reshape(-1,1))

# %%
df.skew()
# Out:
# station            -0.004178
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.120174
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.021647
# LDAPS_WS            0.005937
# LDAPS_LH            0.028141
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.091156
# LDAPS_CC4           0.129974
# LDAPS_PPT1          1.451770
# LDAPS_PPT2          1.637689
# LDAPS_PPT3          1.814526
# LDAPS_PPT4          2.041426
# lat                 0.085377
# lon                -0.289048
# DEM                 0.039591
# Slope               0.233968
# Solar radiation    -0.182349
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# dtype: float64

# %% [markdown]
# #### Observation: Skewness reduced considerably

# %% [markdown]
# ### Separating Dependent and Independent variable

# %%
x=df.copy()
x.drop(['Next_Tmax','Next_Tmin'],axis=1,inplace=True)
ymax=df['Next_Tmax']
ymin=df['Next_Tmin']

# %%
x
# Out:
#       station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0         1.0          28.7          21.4    58.255688     0.271501
# 1         2.0          31.9          21.6    52.263397     0.184890
# 2         3.0          31.6          23.3    48.690479    -0.769141
# 3         4.0          32.0          23.4    58.239788     1.309753
# 4         5.0          31.4          21.9    56.174095     0.110434
# ...       ...           ...           ...          ...          ...
# 7745     21.0          23.1          17.8    24.688997    -1.375942
# 7746     22.0          22.5          17.4    30.094858    -0.803558
# 7747     23.0          23.3          17.1    26.741310    -1.319444
# 7748     24.0          23.3          17.7    24.040634    -1.462026
# 7749     25.0          23.2          17.4    22.933014    -1.466467
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %% [markdown]
# ### Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0     0.000000      0.494318      0.543011     0.488518     0.593474
# 1     0.041667      0.676136      0.553763     0.412406     0.574555
# 2     0.083333      0.659091      0.645161     0.367024     0.366159
# 3     0.125000      0.681818      0.650538     0.488316     0.820267
# 4     0.166667      0.647727      0.569892     0.462078     0.558291
# ...        ...           ...           ...          ...          ...
# 7583  0.833333      0.176136      0.349462     0.062166     0.233611
# 7584  0.875000      0.142045      0.327957     0.130829     0.358641
# 7585  0.916667      0.187500      0.311828     0.088234     0.245952
# 7586  0.958333      0.187500      0.344086     0.053931     0.214807
# 7587  1.000000      0.181818      0.327957     0.039862     0.213837
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# ...

# %% [markdown]
# ### Modelling for Next_Tmax

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as knn
from sklearn.model_selection import cross_val_score

# %%
maxAcc = 0
maxRs = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,ymax,test_size=0.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc > maxAcc:
        maxAcc = acc
        maxRs= i
print('Max r2 score is: ',maxAcc, 'on Random State', maxRs)
# Out:
# Max r2 score is:  0.7961489050617432 on Random State 30

# %%
x_train,x_test,y_train,y_test = train_test_split(x,ymax,test_size=0.20,random_state=maxRs)

# %% [markdown]
# ### a) Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
pred_lr = lr.predict(x_test)
pred_train = lr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2_score:  0.8084398746495552
# R2 score on training data:  0.7655817735710296
# Mean Absolute Error:  1.0549715010401726
# Mean Squared Error:  1.891566505699491
# Root Mean Squared Error:  1.3753423230961415

# %%
score = cross_val_score(lr,x,ymax)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lr)-(score.mean()))*100)
# Out:
# [0.70215123 0.64682543 0.67991133 0.80555743 0.7055109 ]
# 0.7079912650336458
# Difference between R2 Score and Cross Validation Score:  10.04486096159094

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lr, y= y_test, color = 'b')
plt.plot(pred_lr,pred_lr,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Linear Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### b) Random Forest Regressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_RFR))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score:  0.9137726827114587
# R2 score on training data:  0.9859194425432326
# Mean Absolute Error:  0.6975777338603433
# Mean Squared Error:  0.8514543669301723
# Root Mean Squared Error:  0.9227428498396356

# %%
score = cross_val_score(RFR,x,ymax)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_RFR)-(score.mean()))*100)
# Out:
# [0.71296045 0.65103443 0.64831855 0.79706508 0.66418634]
# 0.6947129702208943
# Difference between R2 Score and Cross Validation Score:  21.905971249056442

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_RFR, y= y_test, color = 'b')
plt.plot(pred_RFR,pred_RFR,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Random Forest Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### c) Kneighbour Regressor

# %%
KNN = knn()
KNN.fit(x_train, y_train)
pred_KNN = KNN.predict(x_test)
pred_train = KNN.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_KNN))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_KNN))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_KNN))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# R2_score:  0.8001152927553175
# R2 score on training data:  0.854511519593917
# Mean Absolute Error:  1.079090909090909
# Mean Squared Error:  1.9737678524374176
# Root Mean Squared Error:  1.404908485431495

# %%
score = cross_val_score(KNN,x,ymax)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_KNN)-(score.mean()))*100)
# Out:
# [0.57830783 0.31943843 0.35889634 0.56908535 0.57516031]
# 0.4801776524311457
# Difference between R2 Score and Cross Validation Score:  31.993764032417175

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_KNN, y= y_test, color = 'b')
plt.plot(pred_KNN,pred_KNN,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('KNeighbors Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### d) Gradient Boosting Regressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_gbr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_gbr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_gbr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# R2_score:  0.8686669603570336
# R2 score on training data:  0.8703827805154463
# Mean Absolute Error:  0.8948384946265863
# Mean Squared Error:  1.2968522463945122
# Root Mean Squared Error:  1.138794207218544

# %%
score = cross_val_score(gbr,x,ymax)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_gbr)-(score.mean()))*100)
# Out:
# [0.71095179 0.68725812 0.6717514  0.8092474  0.69352181]
# 0.7145461057217506
# Difference between R2 Score and Cross Validation Score:  15.412085463528303

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_gbr, y= y_test, color = 'grey')
plt.plot(pred_gbr,pred_gbr,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Gradient Boosting Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### e) Lasso Regression

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lasso))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score:  -0.001188257349503008
# R2 score on training data:  0.0
# Mean Absolute Error:  2.5236696381478274
# Mean Squared Error:  9.886265056662351
# Root Mean Squared Error:  3.1442431611855897

# %% [markdown]
# ### f) Ridge Redression

# %%
rd = Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_rd))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score:  0.8077935809819617
# R2 score on training data:  0.7654150535836381
# Mean Absolute Error:  1.0566682222724186
# Mean Squared Error:  1.897948352924894
# Root Mean Squared Error:  1.3776604635848755

# %%
score = cross_val_score(rd,x,ymax)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_rd)-(score.mean()))*100)
# Out:
# [0.70703962 0.64255819 0.67769595 0.80797844 0.70737348]
# 0.7085291351418472
# Difference between R2 Score and Cross Validation Score:  9.92644458401145

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_rd, y= y_test, color = 'violet')
plt.plot(pred_rd,pred_rd,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Ridge Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### g) Decision Tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_dtr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score:  0.8092342923905171
# R2 score on training data:  1.0
# Mean Absolute Error:  0.9871541501976286
# Mean Squared Error:  1.883722002635046
# Root Mean Squared Error:  1.3724875236719078

# %%
score = cross_val_score(dtr,x,ymax)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_dtr)-(score.mean()))*100)
# Out:
# [0.32263467 0.40852558 0.28815746 0.62563259 0.48782382]
# 0.42655482434394615
# Difference between R2 Score and Cross Validation Score:  38.2679468046571

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_dtr, y= y_test, color = 'violet')
plt.plot(pred_dtr,pred_dtr,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('DecisionTreeRegressor', fontsize = 14)
plt.show()

# %% [markdown]
# #### Observation: Since the amount of data is very less hence the nodel is not able to be trained propoerly. As per the data available the best modelling technique would be Ridge regression with R2 score 0.86 and difference between R2score and Cross Validation Score as 9.

# %%
from sklearn.model_selection import GridSearchCV
param = {'fit_intercept':[True,False],'max_iter':[100,200,500,1000],
        'random_state':[1,4,20],'positive':[True,False]}
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'fit_intercept': True, 'max_iter': 100, 'positive': False, 'random_state': 1}

# %%
Model_Next_Tmax = Ridge(fit_intercept = True, max_iter = 100, positive = False, random_state = 1)

# %%
Model_Next_Tmax.fit(x_train,y_train)
pred = Model_Next_Tmax.predict(x_test)
print('R2 Score: ',r2_score(y_test,pred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred))
print('Mean Squared Error: ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score:  0.8077935809819617
# Mean Absolute Error:  1.0566682222724186
# Mean Squared Error:  1.897948352924894
# Root Mean Squared Error:  1.3776604635848755

# %%
import joblib
joblib.dump(Model_Next_Tmax,'Next_Tmax.pki')
# Out:
# ['Next_Tmax.pki']

# %%
model = joblib.load('Next_Tmax.pki')
prediction = model.predict(x_test)
prediction
# Out:
# array([31.64280147, 30.37274008, 31.91265722, ..., 28.87312898,
#        30.20851276, 31.73132046])

# %%
conclusion = pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])

# %%
conclusion
# Out:
#                 0         1          2        3          4          5     \
# Predicted  31.642801  30.37274  31.912657  35.8736  33.168319  26.580554
# Original   36.100000  30.50000  35.100000  37.0000  33.900000  27.100000
#
#                 6          7          8          9     ...       1508  \
# Predicted  28.834942  31.748597  30.287503  28.298226  ...  35.124554
# Original   29.000000  30.200000  27.500000  25.500000  ...  33.700000
#
#                 1509       1510      1511      1512       1513       1514  \
# Predicted  27.955182  31.451144  31.17775  29.29017  25.925417  27.840573
# Original   27.100000  33.600000  32.30000  30.70000  25.400000  26.600000
#
#                 1515       1516      1517
# Predicted  28.873129  30.208513  31.73132
# Original   28.300000  31.600000  32.60000
#
# [2 rows x 1518 columns]

# %% [markdown]
# ### Observation: Accuracy R2 Score 80% with Root Mean Squared Error 1.3

# %% [markdown]
# ### Modelling for Next_Tmin

# %%
maxAcc = 0
maxRs = 0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,ymin,test_size=0.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred = lr.predict(x_test)
    acc = r2_score(y_test,pred)
    if acc > maxAcc:
        maxAcc = acc
        maxRs= i
print('Max r2 score is: ',maxAcc, 'on Random State', maxRs)
# Out:
# Max r2 score is:  0.8486922389864914 on Random State 51

# %%
x_train,x_test,y_train,y_test = train_test_split(x,ymin,test_size=0.20,random_state=maxRs)

# %% [markdown]
# ### a) Linear Regression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
pred_lr = lr.predict(x_test)
pred_train = lr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2_score:  0.8450999527547792
# R2 score on training data:  0.8309641730714473
# Mean Absolute Error:  0.7770089203263542
# Mean Squared Error:  0.9790968287297993
# Root Mean Squared Error:  0.9894932181322919

# %%
score = cross_val_score(lr,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lr)-(score.mean()))*100)
# Out:
# [0.71662654 0.65593185 0.79588315 0.87200114 0.86236706]
# 0.7805619489907103
# Difference between R2 Score and Cross Validation Score:  6.4538003764068925

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lr, y= y_test, color = 'b')
plt.plot(pred_lr,pred_lr,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Linear Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### b) Random Forest Regressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_RFR))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_score:  0.9124737918314192
# R2 score on training data:  0.9867356027108201
# Mean Absolute Error:  0.5677187088274048
# Mean Squared Error:  0.5532382615283273
# Root Mean Squared Error:  0.7437998800270993

# %%
score = cross_val_score(RFR,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_RFR)-(score.mean()))*100)
# Out:
# [0.68153008 0.67017845 0.81529833 0.86496665 0.87750662]
# 0.781896025860024
# Difference between R2 Score and Cross Validation Score:  13.057776597139515

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_RFR, y= y_test, color = 'b')
plt.plot(pred_RFR,pred_RFR,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Random Forest Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### c) Kneighbour Regressor

# %%
KNN = knn()
KNN.fit(x_train, y_train)
pred_KNN = KNN.predict(x_test)
pred_train = KNN.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_KNN))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_KNN))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_KNN))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# R2_score:  0.8029458528403816
# R2 score on training data:  0.8719538002479195
# Mean Absolute Error:  0.8523056653491435
# Mean Squared Error:  1.2455457180500658
# Root Mean Squared Error:  1.1160401955351187

# %%
score = cross_val_score(KNN,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_KNN)-(score.mean()))*100)
# Out:
# [0.44346321 0.07279919 0.52813689 0.58294406 0.69543019]
# 0.46455470732266607
# Difference between R2 Score and Cross Validation Score:  33.83911455177155

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_KNN, y= y_test, color = 'b')
plt.plot(pred_KNN,pred_KNN,color='r')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('KNeighbors Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### d) Gradient Boosting Regressor

# %%
gbr = GradientBoostingRegressor()
gbr.fit(x_train, y_train)
pred_gbr = gbr.predict(x_test)
pred_train = gbr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_gbr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_gbr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_gbr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# R2_score:  0.8914520899553907
# R2 score on training data:  0.90407980518488
# Mean Absolute Error:  0.6505087231335425
# Mean Squared Error:  0.6861128603897412
# Root Mean Squared Error:  0.8283192985737693

# %%
score = cross_val_score(gbr,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_gbr)-(score.mean()))*100)
# Out:
# [0.71714592 0.67542597 0.83465146 0.8759019  0.89380287]
# 0.7993856242054955
# Difference between R2 Score and Cross Validation Score:  9.206646574989518

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_gbr, y= y_test, color = 'grey')
plt.plot(pred_gbr,pred_gbr,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Gradient Boosting Regressor ', fontsize = 14)
plt.show()

# %% [markdown]
# ### e) Lasso Regression

# %%
lasso = Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_lasso))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2_score:  -0.0030074384911946694
# R2 score on training data:  0.0
# Mean Absolute Error:  1.977401766392526
# Mean Squared Error:  6.3398392685088565
# Root Mean Squared Error:  2.5179037448855857

# %%
score = cross_val_score(lasso,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_lasso)-(score.mean()))*100)
# Out:
# [-0.27872089 -0.34159268 -0.08435595 -0.04162371 -0.00925796]
# -0.1511102373794106
# Difference between R2 Score and Cross Validation Score:  14.810279888821592

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_lasso, y= y_test, color = 'grey')
plt.plot(pred_lasso,pred_lasso,color='black')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Lasso Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### f) Rigde Regression

# %%
rd = Ridge()
rd.fit(x_train, y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_rd))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_score:  0.8449517139399999
# R2 score on training data:  0.8309465120708408
# Mean Absolute Error:  0.777443459419118
# Mean Squared Error:  0.9800338210421082
# Root Mean Squared Error:  0.9899665757196594

# %%
score = cross_val_score(rd,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_rd)-(score.mean()))*100)
# Out:
# [0.71679872 0.65662965 0.79585268 0.87158321 0.86296138]
# 0.7807651258105056
# Difference between R2 Score and Cross Validation Score:  6.418658812949429

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_rd, y= y_test, color = 'violet')
plt.plot(pred_rd,pred_rd,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('Ridge Regression ', fontsize = 14)
plt.show()

# %% [markdown]
# ### g) Decission Tree Regressor

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train, y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print('R2_score: ',r2_score(y_test,pred_dtr))
print('R2 score on training data: ',r2_score(y_train,pred_train))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error: ',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_score:  0.7900243992688643
# R2 score on training data:  1.0
# Mean Absolute Error:  0.8504611330698287
# Mean Squared Error:  1.327220026350461
# Root Mean Squared Error:  1.1520503575584102

# %%
score = cross_val_score(dtr,x,ymin)
print(score)
print(score.mean())
print('Difference between R2 Score and Cross Validation Score: ', (r2_score(y_test,pred_dtr)-(score.mean()))*100)
# Out:
# [0.39582623 0.44550033 0.60699593 0.71973453 0.72181463]
# 0.577974329007561
# Difference between R2 Score and Cross Validation Score:  21.20500702613033

# %%
plt.figure(figsize=(5,5))
plt.scatter(x=pred_dtr, y= y_test, color = 'violet')
plt.plot(pred_dtr,pred_dtr,color='indigo')
plt.xlabel("Actual",fontsize = 12)
plt.ylabel("Predicted", fontsize = 12)
plt.title('DecisionTreeRegressor', fontsize = 14)
plt.show()

# %% [markdown]
# #### Observation: Since the amount of data is very less hence the nodel is not able to be trained propoerly. As per the data available the best modelling technique would be Ridge regression with R2 score 0.84 and difference between R2score and Cross Validation Score as 6.

# %%
from sklearn.model_selection import GridSearchCV
param = {'fit_intercept':[True,False],'max_iter':[100,200,500,1000],
        'random_state':[1,4,20],'positive':[True,False]}
gscv=GridSearchCV(Ridge(),param,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'fit_intercept': True, 'max_iter': 100, 'positive': False, 'random_state': 1}

# %%
Model_Next_Tmin = Ridge(fit_intercept = True, max_iter = 100, positive = False, random_state = 1)

# %%
Model_Next_Tmin.fit(x_train,y_train)
pred = Model_Next_Tmin.predict(x_test)
print('R2 Score: ',r2_score(y_test,pred))
print('Mean Absolute Error: ',mean_absolute_error(y_test,pred))
print('Mean Squared Error: ',mean_squared_error(y_test,pred))
print('Root Mean Squared Error: ',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score:  0.8449517139399999
# Mean Absolute Error:  0.777443459419118
# Mean Squared Error:  0.9800338210421082
# Root Mean Squared Error:  0.9899665757196594

# %%
import joblib
joblib.dump(Model_Next_Tmin,'Next_Tmin.pki')
# Out:
# ['Next_Tmin.pki']

# %%
model = joblib.load('Next_Tmin.pki')
prediction = model.predict(x_test)
prediction
# Out:
# array([24.3713545 , 21.4681987 , 17.83564477, ..., 21.9545279 ,
#        22.63202968, 21.57049346])

# %%
conclusion = pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])

# %%
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  24.371355  21.468199  17.835645  18.170412  26.786891  25.893355
# Original   24.700000  20.600000  17.100000  18.600000  26.600000  25.700000
#
#                 6          7          8          9     ...       1508  \
# Predicted  18.938352  27.116103  17.286432  25.847554  ...  24.410104
# Original   17.600000  26.800000  19.100000  26.900000  ...  23.500000
#
#                 1509       1510       1511       1512      1513       1514  \
# Predicted  23.673357  25.398015  26.952545  21.493623  24.50271  21.459148
# Original   23.800000  25.000000  26.800000  23.100000  23.70000  22.000000
#
#                 1515      1516       1517
# Predicted  21.954528  22.63203  21.570493
# Original   22.300000  22.80000  23.000000
#
# [2 rows x 1518 columns]

# %% [markdown]
# ### Observation: for Next_Tmin Accuracy R2 Score is 84% with Root Mean Sqaured Error .98
